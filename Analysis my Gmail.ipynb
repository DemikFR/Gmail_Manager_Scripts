# %% [markdown]
# ## Get the emails

# %%
import imaplib
import email
import yaml
import concurrent.futures
import pandas as pd

# %% [markdown]
# ### Open the file that have the gmail credentials

# %%
with open('credentials.yaml') as f:
    credentials = f.read()

# %% [markdown]
# ### Get the User and Password

# %%
my_credentials = yaml.load(credentials, Loader = yaml.FullLoader)
user, password = my_credentials['user'], my_credentials['password']

# %% [markdown]
# ### Connect to Gmail

# %%
imap_url = 'imap.gmail.com'
my_email = imaplib.IMAP4_SSL(imap_url)
my_email.login(user, password)
# Out:
# ('OK', [b'demik.freitast2d18@gmail.com authenticated (Success)'])

# %% [markdown]
# ### Number of emails in my inbox

# %%
my_email.select('inbox')[1][0].decode()
# Out:
# '18567'

# %% [markdown]
# ### Import emails from inbox and then put them in a list

# %%
emails = my_email.search(None, 'ALL')
emails_ids = emails[1][0].decode().split()

# %%
def fetch(id):
  with concurrent.futures.ThreadPoolExecutor() as executor:
    data = executor.submit(my_email.fetch, str(id), '(RFC822)')
    return data.result()[1][0][1]

## Test: fetch(1)

# %%
# Get the message and 

emails_list = []

for i in emails_ids:
      msg = email.message_from_string(str(fetch(i),'ISO-8859-1'))
      emails_list.append({'Date': msg['Date'], 'From': msg['From'], 'Subject': msg['Subject']})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-7a9384a0acbd> in <module>
#       4
#       5 for i in emails_ids:
# ----> 6       msg = email.message_from_string(str(fetch(i),'ISO-8859-1'))
#       7       emails_list.append({'Date': msg['Date'], 'From': msg['From'], 'Subject': msg['Subject']})
#
# <ipython-input-7-56950017efa3> in fetch(id)
#       2   with concurrent.futures.ThreadPoolExecutor() as executor:
#       3     data = executor.submit(my_email.fetch, str(id), '(RFC822)')
# ----> 4     return data.result()[1][0][1]
#       5
#       6 ## Test: fetch(1)
#
# /usr/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     439                     return self.__get_result()
#     440
# --> 441                 self._condition.wait(timeout)
#     442
#     443                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Put email data in a dataframe

# %%
df = pd.DataFrame(emails_list, columns=['Date', 'From', 'Subject'])
df
# Out:
#                                        Date  \
# 0      Sun, 2 Sep 2018 14:49:12 +0000 (UTC)
# 1      Mon, 3 Sep 2018 22:00:08 +0000 (UTC)
# 2      Tue, 4 Sep 2018 12:36:39 +0000 (UTC)
# 3      Wed, 5 Sep 2018 09:08:41 +0000 (UTC)
# 4      Thu, 6 Sep 2018 15:12:09 +0000 (UTC)
# ...                                     ...
# 18341       Mon, 13 Mar 2023 07:10:45 -0500
# 18342       Mon, 13 Mar 2023 12:32:07 +0000
# 18343       Mon, 13 Mar 2023 08:03:05 -0500
# 18344       Mon, 13 Mar 2023 08:34:03 -0500
# 18345       Mon, 13 Mar 2023 09:07:59 -0500
#
#                                                                     From  \
# 0      Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 1                                  Ryan Souza <invitations@linkedin.com>
# 2      Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 3                                           LinkedIn <news@linkedin.com>
# 4      Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# ...                                                                  ...
# 18341            "Jacqueline Oliveira | Alura" <jacqueline@alura.com.br>
# 18342                     "ABA English" <no-reply@emails.abaenglish.com>
# 18343                        "Aprova Total" <contato@aprovatotal.com.br>
# 18344                     "Diego | Rocketseat" <diego@rocketseat.com.br>
# 18345    =?utf-8?Q?B=C3=A1rbara_da_DIO?=\r\n <ead@digitalinnovation.one>
#
#                                                                                                                   Subject
# 0                                                                                            Demik, bem-vindo ao LinkedIn
# 1                       =?UTF-8?Q?Demik,_voc=C3=AA_poderia_me_adici?=\r\n =?UTF-8?Q?onar_=C3=A0_sua_rede_no_LinkedIn=3F?=
# 2                                                              Baixe o aplicativo e nunca perca uma chance de se conectar
# 3                                                                            =?UTF-8?Q?Arte_n=C3=A3o_=C3=A9_brincadeira?=
# 4                                                      =?UTF-8?Q?Demik,_veja_quem_voc=C3=AA_j=C3=A1_conhece_no_LinkedIn?=
# ...                                                                                                                   ...
# 18341     =?utf-8?Q?[Imers=C3=A3o_Java]_Um_novo_desafio_para_voc=C3=AA,_D?=\r\n =?utf-8?Q?emik_Soares_Farias_de_Freitas?=
# 18342  =?utf-8?B?IE8gMTcgZGUgbWFyw6dvIMOpIFNhaW50IFBhdHJpY2sncyBEYXkg?=\r\n\t=?utf-8?B?ZSB2b2PDqiBlc3TDoSBjb20gc29ydGUg?=
# 18343                                                                             LIBEROU: comece agora o Extensivo Enem!
# 18344                                                                =?utf-8?Q?Viva_uma_experi=C3=AAncia_transformadora?=
# 18345                                                                         Torne-se um especialista em Cloud Computing
#
# [18346 rows x 3 columns]

# %%
df1 = df.copy()
df1
# Out:
#                                        Date  \
# 0      Sun, 2 Sep 2018 14:49:12 +0000 (UTC)
# 1      Mon, 3 Sep 2018 22:00:08 +0000 (UTC)
# 2      Tue, 4 Sep 2018 12:36:39 +0000 (UTC)
# 3      Wed, 5 Sep 2018 09:08:41 +0000 (UTC)
# 4      Thu, 6 Sep 2018 15:12:09 +0000 (UTC)
# ...                                     ...
# 18341       Mon, 13 Mar 2023 07:10:45 -0500
# 18342       Mon, 13 Mar 2023 12:32:07 +0000
# 18343       Mon, 13 Mar 2023 08:03:05 -0500
# 18344       Mon, 13 Mar 2023 08:34:03 -0500
# 18345       Mon, 13 Mar 2023 09:07:59 -0500
#
#                                                                     From  \
# 0      Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 1                                  Ryan Souza <invitations@linkedin.com>
# 2      Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 3                                           LinkedIn <news@linkedin.com>
# 4      Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# ...                                                                  ...
# 18341            "Jacqueline Oliveira | Alura" <jacqueline@alura.com.br>
# 18342                     "ABA English" <no-reply@emails.abaenglish.com>
# 18343                        "Aprova Total" <contato@aprovatotal.com.br>
# 18344                     "Diego | Rocketseat" <diego@rocketseat.com.br>
# 18345    =?utf-8?Q?B=C3=A1rbara_da_DIO?=\r\n <ead@digitalinnovation.one>
#
#                                                                                                                   Subject
# 0                                                                                            Demik, bem-vindo ao LinkedIn
# 1                       =?UTF-8?Q?Demik,_voc=C3=AA_poderia_me_adici?=\r\n =?UTF-8?Q?onar_=C3=A0_sua_rede_no_LinkedIn=3F?=
# 2                                                              Baixe o aplicativo e nunca perca uma chance de se conectar
# 3                                                                            =?UTF-8?Q?Arte_n=C3=A3o_=C3=A9_brincadeira?=
# 4                                                      =?UTF-8?Q?Demik,_veja_quem_voc=C3=AA_j=C3=A1_conhece_no_LinkedIn?=
# ...                                                                                                                   ...
# 18341     =?utf-8?Q?[Imers=C3=A3o_Java]_Um_novo_desafio_para_voc=C3=AA,_D?=\r\n =?utf-8?Q?emik_Soares_Farias_de_Freitas?=
# 18342  =?utf-8?B?IE8gMTcgZGUgbWFyw6dvIMOpIFNhaW50IFBhdHJpY2sncyBEYXkg?=\r\n\t=?utf-8?B?ZSB2b2PDqiBlc3TDoSBjb20gc29ydGUg?=
# 18343                                                                             LIBEROU: comece agora o Extensivo Enem!
# 18344                                                                =?utf-8?Q?Viva_uma_experi=C3=AAncia_transformadora?=
# 18345                                                                         Torne-se um especialista em Cloud Computing
#
# [18346 rows x 3 columns]

# %%
df1.dtypes
# Out:
# Date       object
# From       object
# Subject    object
# dtype: object

# %% [markdown]
# ### Resolve encoding issues

# %%
pd.set_option('max_colwidth', None)

# %% [markdown]
# #### Convert column encode 'From'

# %%
df1['From'] = df1['From'].apply(lambda x: email.header.decode_header(x)[0][0])

# %%
df1['From'] = df1['From'].apply(lambda x: x.decode('utf-8', 'replace') if isinstance(x, bytes) else x)

# %% [markdown]
# #### Convert column encode 'Subject'

# %%
df1['Subject'] = df1['Subject'].apply(lambda x: email.header.decode_header(x)[0][0])

# %%
df1['Subject'] = df1['Subject'].apply(lambda x: x.decode('utf-8', 'replace') if isinstance(x, bytes) else x)

# %%
df1.head(10)
# Out:
#                                     Date  \
# 0   Sun, 2 Sep 2018 14:49:12 +0000 (UTC)
# 1   Mon, 3 Sep 2018 22:00:08 +0000 (UTC)
# 2   Tue, 4 Sep 2018 12:36:39 +0000 (UTC)
# 3   Wed, 5 Sep 2018 09:08:41 +0000 (UTC)
# 4   Thu, 6 Sep 2018 15:12:09 +0000 (UTC)
# 5   Fri, 7 Sep 2018 15:11:04 +0000 (UTC)
# 6   Sat, 8 Sep 2018 00:14:30 +0000 (UTC)
# 7   Sun, 9 Sep 2018 14:59:32 +0000 (UTC)
# 8  Mon, 10 Sep 2018 06:09:15 +0000 (UTC)
# 9  Mon, 10 Sep 2018 15:05:29 +0000 (UTC)
#
#                                                                 From  \
# 0  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 1                              Ryan Souza <invitations@linkedin.com>
# 2  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 3                                       LinkedIn <news@linkedin.com>
# 4  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 5  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 6              Derek Freitas via LinkedIn <invitations@linkedin.com>
# 7  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 8                                               Conexões do LinkedIn
# 9  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
#
#                                                       Subject
# 0                                Demik, bem-vindo ao LinkedIn
# 1    Demik, você poderia me adicionar à sua rede no LinkedIn?
# 2  Baixe o aplicativo e nunca perca uma chance de se conectar
# 3                                      Arte não é brincadeira
# 4                Demik, veja quem você já conhece no LinkedIn
# 5   Demik, ajude seus contatos a encontrarem você no LinkedIn
# 6      Demik, inicie uma conversa com sua nova conexão, Derek
# 7                Demik, veja quem você já conhece no LinkedIn
# 8                Demik, veja quem você já conhece no LinkedIn
# 9                Demik, veja quem você já conhece no LinkedIn

# %% [markdown]
# ### Clear the 'From' column

# %% [markdown]
# #### Get the sender's email address

# %%
df1['Email'] = df1['From'].str.extract(r'<(.+)>')

# %%
df1.head(10)
# Out:
#                                     Date  \
# 0   Sun, 2 Sep 2018 14:49:12 +0000 (UTC)
# 1   Mon, 3 Sep 2018 22:00:08 +0000 (UTC)
# 2   Tue, 4 Sep 2018 12:36:39 +0000 (UTC)
# 3   Wed, 5 Sep 2018 09:08:41 +0000 (UTC)
# 4   Thu, 6 Sep 2018 15:12:09 +0000 (UTC)
# 5   Fri, 7 Sep 2018 15:11:04 +0000 (UTC)
# 6   Sat, 8 Sep 2018 00:14:30 +0000 (UTC)
# 7   Sun, 9 Sep 2018 14:59:32 +0000 (UTC)
# 8  Mon, 10 Sep 2018 06:09:15 +0000 (UTC)
# 9  Mon, 10 Sep 2018 15:05:29 +0000 (UTC)
#
#                                                                 From  \
# 0  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 1                              Ryan Souza <invitations@linkedin.com>
# 2  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 3                                       LinkedIn <news@linkedin.com>
# 4  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 5  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 6              Derek Freitas via LinkedIn <invitations@linkedin.com>
# 7  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
# 8                                               Conexões do LinkedIn
# 9  Equipe de boas-vindas do LinkedIn <messages-noreply@linkedin.com>
#
#                                                       Subject  \
# 0                                Demik, bem-vindo ao LinkedIn
# 1    Demik, você poderia me adicionar à sua rede no LinkedIn?
# 2  Baixe o aplicativo e nunca perca uma chance de se conectar
# 3                                      Arte não é brincadeira
# 4                Demik, veja quem você já conhece no LinkedIn
# 5   Demik, ajude seus contatos a encontrarem você no LinkedIn
# 6      Demik, inicie uma conversa com sua nova conexão, Derek
# 7                Demik, veja quem você já conhece no LinkedIn
# 8                Demik, veja quem você já conhece no LinkedIn
# 9                Demik, veja quem você já conhece no LinkedIn
#
#                            Email
# 0  messages-noreply@linkedin.com
# 1       invitations@linkedin.com
# 2  messages-noreply@linkedin.com
# 3              news@linkedin.com
# 4  messages-noreply@linkedin.com
# 5  messages-noreply@linkedin.com
# 6       invitations@linkedin.com
# 7  messages-noreply@linkedin.com
# 8                            NaN
# 9  messages-noreply@linkedin.com

# %% [markdown]
# #### Get the sender's name

# %%
df1['Sender'] = df1['From'].str.extract(r'(?:"|^)(.*?)(?:"|\s)(?:\s*<|$)')

# %% [markdown]
# #### Delete From column (useless)

# %%
del df1['From']

# %%
df1.sample(20)
# Out:
#                                         Date  \
# 3815         Fri, 16 Jul 2021 12:00:54 +0000
# 17201        Tue, 07 Feb 2023 22:52:48 +0000
# 9580         Tue, 31 May 2022 12:31:55 -0500
# 13385        Fri, 21 Oct 2022 20:40:09 -0500
# 800          Wed, 20 May 2020 16:26:18 +0000
# 13611  Sat, 29 Oct 2022 09:35:03 -0700 (PDT)
# 12646        Wed, 28 Sep 2022 01:58:46 +0000
# 4297   Thu, 19 Aug 2021 10:59:53 +0000 (UTC)
# 14034        Fri, 11 Nov 2022 16:33:17 +0000
# 15227        Sat, 10 Dec 2022 19:02:40 -0600
# 12581        Sun, 25 Sep 2022 15:02:31 -0700
# 2822         Thu, 13 May 2021 21:26:59 +0000
# 8188         Fri, 01 Apr 2022 09:04:02 -0600
# 5405   Thu, 28 Oct 2021 14:04:59 +0000 (UTC)
# 18212   Wed, 8 Mar 2023 20:34:47 +0000 (UTC)
# 10898  Wed, 20 Jul 2022 10:13:49 -0700 (PDT)
# 17438  Tue, 14 Feb 2023 10:07:19 +0000 (UTC)
# 4954          Mon, 4 Oct 2021 18:19:42 +0000
# 16514        Wed, 18 Jan 2023 11:17:11 -0600
# 1098              22 Jul 2020 18:36:26 +0000
#
#                                                                            Subject  \
# 3815                                           Novos projetos no Freelancer.com.br
# 17201                                                    🐱 De R$148 por R$68/mês 🦁
# 9580                                            Meu artigo sumiu. O que aconteceu?
# 13385                                       Esse e-mail tem validade de 60 minutos
# 800    Richard Dawkins Tweeted: RT @center4inquiry: Null and Void - Stare\r\n i...
# 13611       ATÉ 59% OFF 👔👖 Moda masculina áfrica vestuário longo pullovers vest...
# 12646                                            Novos boletos emitidos no seu CPF
# 4297                                   Demik, 100 novos anuncios para o seu perfil
# 14034                                                    We Want to Hear From You!
# 15227                                             Sua chance termina em 59 minutos
# 12581                                  Eletrodomésticos com até 43% OFF! Aproveite
# 2822       Global Teacher Prize Tweeted: “This award can help elevate your voic...
# 8188                                                   Abril chegou e VOCÊ GANHOU!
# 5405                                                                        O que
# 18212                        Demik, your application was sent to Construtora Tenda
# 10898                                                      Recomendados para Demik
# 17438                                   Can we continue to keep in touch with you?
# 4954                                           Novos projetos no Freelancer.com.br
# 16514                                                       Salários de 5 dígitos?
# 1098                       😊 Descubra aqui como está o processo da sua candidatura
#
#                                     Email                     Sender
# 3815            noreply@freelancer.com.br                 Freelancer
# 17201                     help@cambly.com              Cambly Brasil
# 9580            ead@digitalinnovation.one                 Equipe DIO
# 13385                          ead@dio.me              Felipe Aguiar
# 800                      info@twitter.com                    Twitter
# 13611  buyer-info15.m@mail.aliexpress.com                 AliExpress
# 12646             todomundo@nubank.com.br                     Nubank
# 4297              avisovagas@catho.com.br  Vagas de Emprego na Catho
# 14034                ben@hello.beacons.ai                        Ben
# 15227                          ead@dio.me             Renan Oliveira
# 12581                                 NaN                        NaN
# 2822                     info@twitter.com                    Twitter
# 8188                tim@compre-tim.com.br                        TIM
# 5405     news@professorsamuelcunha.com.br     Professor Samuel Cunha
# 18212           jobs-noreply@linkedin.com                   LinkedIn
# 10898       interest8@mail.aliexpress.com                 AliExpress
# 17438      accenture_global@accenture.com       Accenture Recruiting
# 4954            noreply@freelancer.com.br                 Freelancer
# 16514                          ead@dio.me              Felipe Aguiar
# 1098                 info@infojobs.com.br                   InfoJobs

# %% [markdown]
# ### Reorder columns

# %%
df1 = df1[['Date', 'Sender', 'Email', 'Subject']]
df1
# Out:
#                                        Date  \
# 0      Sun, 2 Sep 2018 14:49:12 +0000 (UTC)
# 1      Mon, 3 Sep 2018 22:00:08 +0000 (UTC)
# 2      Tue, 4 Sep 2018 12:36:39 +0000 (UTC)
# 3      Wed, 5 Sep 2018 09:08:41 +0000 (UTC)
# 4      Thu, 6 Sep 2018 15:12:09 +0000 (UTC)
# ...                                     ...
# 18341       Mon, 13 Mar 2023 07:10:45 -0500
# 18342       Mon, 13 Mar 2023 12:32:07 +0000
# 18343       Mon, 13 Mar 2023 08:03:05 -0500
# 18344       Mon, 13 Mar 2023 08:34:03 -0500
# 18345       Mon, 13 Mar 2023 09:07:59 -0500
#
#                                   Sender                           Email  \
# 0      Equipe de boas-vindas do LinkedIn   messages-noreply@linkedin.com
# 1                             Ryan Souza        invitations@linkedin.com
# 2      Equipe de boas-vindas do LinkedIn   messages-noreply@linkedin.com
# 3                               LinkedIn               news@linkedin.com
# 4      Equipe de boas-vindas do LinkedIn   messages-noreply@linkedin.com
# ...                                  ...                             ...
# 18341        Jacqueline Oliveira | Alura         jacqueline@alura.com.br
# 18342                        ABA English  no-reply@emails.abaenglish.com
# 18343                       Aprova Total      contato@aprovatotal.com.br
# 18344                 Diego | Rocketseat         diego@rocketseat.com.br
# 18345                                NaN                             NaN
#
#                                                                         Subject
# 0                                                  Demik, bem-vindo ao LinkedIn
# 1                      Demik, você poderia me adicionar à sua rede no LinkedIn?
# 2                    Baixe o aplicativo e nunca perca uma chance de se conectar
# 3                                                        Arte não é brincadeira
# 4                                  Demik, veja quem você já conhece no LinkedIn
# ...                                                                         ...
# 18341  [Imersão Java] Um novo desafio para você, Demik Soares Farias de Freitas
# 18342                O 17 de março é Saint Patrick's Day e você está com sorte
# 18343                                   LIBEROU: comece agora o Extensivo Enem!
# 18344                                       Viva uma experiência transformadora
# 18345                               Torne-se um especialista em Cloud Computing
#
# [18346 rows x 4 columns]

# %% [markdown]
# ### Convert data format

# %% [markdown]
# #### Extract the usefull date

# %%
df1['Date'] = df1['Date'].str.extract(r'(\d+ \w{3} \d+)')

# %%
df1['Date'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Verify all the month abbreviations

# %%
df1['Date'].str.extract(r'(\w{3})').squeeze().unique()
# Out:
# array(['Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May',
#        'Jun', 'Jul', 'Aug', 'ago'], dtype=object)

# %% [markdown]
# #### For some reason there is a month like 'ago' instead of 'Aug', it should be replaced.

# %%
df1['Date'] = df1['Date'].str.replace('ago', 'Aug')

# %%
df1
# Out:
#               Date                             Sender  \
# 0       2 Sep 2018  Equipe de boas-vindas do LinkedIn
# 1       3 Sep 2018                         Ryan Souza
# 2       4 Sep 2018  Equipe de boas-vindas do LinkedIn
# 3       5 Sep 2018                           LinkedIn
# 4       6 Sep 2018  Equipe de boas-vindas do LinkedIn
# ...            ...                                ...
# 18341  13 Mar 2023        Jacqueline Oliveira | Alura
# 18342  13 Mar 2023                        ABA English
# 18343  13 Mar 2023                       Aprova Total
# 18344  13 Mar 2023                 Diego | Rocketseat
# 18345  13 Mar 2023                                NaN
#
#                                 Email  \
# 0       messages-noreply@linkedin.com
# 1            invitations@linkedin.com
# 2       messages-noreply@linkedin.com
# 3                   news@linkedin.com
# 4       messages-noreply@linkedin.com
# ...                               ...
# 18341         jacqueline@alura.com.br
# 18342  no-reply@emails.abaenglish.com
# 18343      contato@aprovatotal.com.br
# 18344         diego@rocketseat.com.br
# 18345                             NaN
#
#                                                                         Subject
# 0                                                  Demik, bem-vindo ao LinkedIn
# 1                      Demik, você poderia me adicionar à sua rede no LinkedIn?
# 2                    Baixe o aplicativo e nunca perca uma chance de se conectar
# 3                                                        Arte não é brincadeira
# 4                                  Demik, veja quem você já conhece no LinkedIn
# ...                                                                         ...
# 18341  [Imersão Java] Um novo desafio para você, Demik Soares Farias de Freitas
# 18342                O 17 de março é Saint Patrick's Day e você está com sorte
# 18343                                   LIBEROU: comece agora o Extensivo Enem!
# 18344                                       Viva uma experiência transformadora
# 18345                               Torne-se um especialista em Cloud Computing
#
# [18346 rows x 4 columns]

# %%
df1['Date'] = pd.to_datetime(df1['Date'], format='%d %b %Y').dt.strftime('%d/%m/%Y')
df1
# Out:
#              Date                             Sender  \
# 0      02/09/2018  Equipe de boas-vindas do LinkedIn
# 1      03/09/2018                         Ryan Souza
# 2      04/09/2018  Equipe de boas-vindas do LinkedIn
# 3      05/09/2018                           LinkedIn
# 4      06/09/2018  Equipe de boas-vindas do LinkedIn
# ...           ...                                ...
# 18341  13/03/2023        Jacqueline Oliveira | Alura
# 18342  13/03/2023                        ABA English
# 18343  13/03/2023                       Aprova Total
# 18344  13/03/2023                 Diego | Rocketseat
# 18345  13/03/2023                                NaN
#
#                                 Email  \
# 0       messages-noreply@linkedin.com
# 1            invitations@linkedin.com
# 2       messages-noreply@linkedin.com
# 3                   news@linkedin.com
# 4       messages-noreply@linkedin.com
# ...                               ...
# 18341         jacqueline@alura.com.br
# 18342  no-reply@emails.abaenglish.com
# 18343      contato@aprovatotal.com.br
# 18344         diego@rocketseat.com.br
# 18345                             NaN
#
#                                                                         Subject
# 0                                                  Demik, bem-vindo ao LinkedIn
# 1                      Demik, você poderia me adicionar à sua rede no LinkedIn?
# 2                    Baixe o aplicativo e nunca perca uma chance de se conectar
# 3                                                        Arte não é brincadeira
# 4                                  Demik, veja quem você já conhece no LinkedIn
# ...                                                                         ...
# 18341  [Imersão Java] Um novo desafio para você, Demik Soares Farias de Freitas
# 18342                O 17 de março é Saint Patrick's Day e você está com sorte
# 18343                                   LIBEROU: comece agora o Extensivo Enem!
# 18344                                       Viva uma experiência transformadora
# 18345                               Torne-se um especialista em Cloud Computing
#
# [18346 rows x 4 columns]

# %% [markdown]
# ### Drop the columns

# %%
df1 = df1.dropna(subset=['Sender', 'Email'], thresh=2)

# %% [markdown]
# ### Save the dataframe to CSV

# %%
df1.to_csv('Emails_Dataset.csv', sep=';', encoding='utf-8')
